# %%
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from osgeo import gdal
# %matplotlib inline

# %%
import glob

# %%
path = 'LC08_L1TP_141041_20200207_20200211_01_T1/'

# %% [markdown]
# <h2>Code to open Raster File</h2>

# %%
LSband2 = os.path.join(path,"LC08_L1TP_141041_20200207_20200211_01_T1_B2.TIF") 
LSband3 = os.path.join(path,"LC08_L1TP_141041_20200207_20200211_01_T1_B3.TIF")
LSband4 = os.path.join(path,"LC08_L1TP_141041_20200207_20200211_01_T1_B4.TIF")


#Plot image in matplotlib library
plt.imshow(mpimg.imread(LSband2))

# %%
blue = gdal.Open(LSband2)
green = gdal.Open(LSband2)
red = gdal.Open(LSband2)

# %% [markdown]
# ------------------------------

# %% [markdown]
# <h3>To get Projection Parameter</h3>

# %%
from osgeo import osr

# %%
proj = blue.GetProjection()
proj
# Out:
# 'PROJCS["WGS 84 / UTM zone 45N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",87],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32645"]]'

# %% [markdown]
# ---------------------
